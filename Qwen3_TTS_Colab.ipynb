# %% [markdown]
# <a href="https://colab.research.google.com/github/solomon382/Odd-Jobs/blob/main/Qwen3_TTS_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 🏷️ **Credits & License**
#
# * 🔗 [Qwen3-TTS GitHub Repository](https://github.com/QwenLM/Qwen3-TTS)
# * 🤗 [Qwen3-TTS on Hugging Face](https://huggingface.co/collections/Qwen/qwen3-tts)
# * 📄 **License**: Provided under the [Apache License 2.0](https://github.com/QwenLM/Qwen3-TTS?tab=Apache-2.0-1-ov-file)
# * 🤗 [Try Qwen3-TTS on HuggingFace Space](https://huggingface.co/spaces/Qwen/Qwen3-TTS)
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install Qwen3-TTS
# %cd /content/
# !rm -rf /content/Qwen3-TTS-Colab
# !git clone https://github.com/NeuralFalconYT/Qwen3-TTS-Colab.git
# !git clone https://github.com/QwenLM/Qwen3-TTS.git
# %cd Qwen3-TTS
# !pip install -e .
# !pip install faster-whisper==1.1.1
# !pip install ctranslate2==4.5.0
# !pip install pysrt
# !pip install sentencex
from IPython.display import Audio,display
from IPython.display import clear_output
import time
clear_output()

display(Audio("https://raw.githubusercontent.com/NeuralFalconYT/Useful-Function/refs/heads/main/audio/warning.mp3", autoplay=True))
time.sleep(6)
clear_output()
# time.sleep(5)
# import os
# os.kill(os.getpid(), 9)

# %%
# %cd /content/Qwen3-TTS-Colab
# !python app.py --share --debug
# Out:
# /content/Qwen3-TTS-Colab
# 2026-03-12 05:33:05.438533: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773293585.459041    1832 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773293585.465826    1832 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773293585.482901    1832 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773293585.482930    1832 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773293585.482934    1832 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773293585.482937    1832 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-12 05:33:05.487541: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ********
# Warning: flash-attn is not installed. Will only run the manual PyTorch version. Please install flash-attn for faster inference.
# ********
#
# /bin/sh: 1: sox: not found
# WARNING:sox:SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.
#
# /content/Qwen3-TTS-Colab/app.py:354: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="Qwen3-TTS Demo") as demo:
# /content/Qwen3-TTS-Colab/app.py:354: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="Qwen3-TTS Demo") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://1b44bf1ac2e72e0774.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Processing 1 chunks...
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# README.md: 3.21kB [00:00, 14.1MB/s]
#
# preprocessor_config.json: 100% 127/127 [00:00<00:00, 922kB/s]
#
# generation_config.json: 100% 245/245 [00:00<00:00, 1.56MB/s]
#
# merges.txt: 0.00B [00:00, ?B/s]
#
# config.json: 0.00B [00:00, ?B/s]
#
#
# config.json: 0.00B [00:00, ?B/s]
#
# config.json: 4.42kB [00:00, 792kB/s]
# config.json: 2.34kB [00:00, 740kB/s]
# .gitattributes: 1.52kB [00:00, 123kB/s]
# merges.txt: 1.67MB [00:00, 29.9MB/s]
#
# configuration.json: 100% 76.0/76.0 [00:00<00:00, 694kB/s]
#
# model.safetensors:   0% 0.00/3.83G [00:00<?, ?B/s]
#
# preprocessor_config.json: 100% 234/234 [00:00<00:00, 2.32MB/s]
#
#
# vocab.json: 0.00B [00:00, ?B/s]
#
#
# tokenizer_config.json: 7.34kB [00:00, 27.2MB/s]
#
#
#
# vocab.json: 2.78MB [00:00, 49.8MB/s]
#
# model.safetensors:   0% 0.00/3.83G [00:00<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.83G [00:00<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.83G [00:00<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.83G [00:00<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.83G [00:01<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/3.83G [00:01<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:  10% 67.1M/682M [00:01<00:01, 333MB/s]
# model.safetensors:   0% 0.00/3.83G [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/3.83G [00:01<?, ?B/s]
# model.safetensors:   2% 67.1M/3.83G [00:01<00:09, 405MB/s]
#
#
# speech_tokenizer/model.safetensors:  20% 134M/682M [00:01<00:03, 155MB/s]
#
#
# speech_tokenizer/model.safetensors:  39% 268M/682M [00:05<00:07, 52.0MB/s]
# model.safetensors:   7% 268M/3.83G [00:06<01:09, 51.2MB/s]
#
#
# speech_tokenizer/model.safetensors:  92% 630M/682M [00:09<00:00, 74.4MB/s]
#
#
# speech_tokenizer/model.safetensors: 100% 682M/682M [00:09<00:00, 69.6MB/s]
#
# model.safetensors:  23% 872M/3.83G [00:12<00:34, 85.2MB/s]
# model.safetensors:  49% 1.88G/3.83G [00:17<00:15, 130MB/s]
# model.safetensors:  73% 2.82G/3.83G [00:22<00:06, 161MB/s]
# model.safetensors: 100% 3.83G/3.83G [00:27<00:00, 139MB/s]
# Fetching 13 files: 100% 13/13 [00:27<00:00,  2.15s/it]
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Stitching 1 audio files...
# Processing 1 chunks...
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Stitching 1 audio files...
